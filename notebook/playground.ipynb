# %%
# %load_ext autoreload
# %autoreload 2
import sys
sys.path.insert(0, '..')
import pandas as pd
import numpy as np
from libgen.file_io import *
from libgen.search_utils import *
from libgen.Tylos import *
from libgen.spectra_plotter import EIC
from libgen.constant import *
from libgen.spectra_plotter import *
from libgen.libgen_core import *
from libgen.chem_utils import *
home_dir = '/Users/fanzhoukong/Downloads'
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
std_list = pd.read_csv(os.path.join(home_dir, 'Copy of WCMS_std_list_curated)LMV 123 - liquid.csv'))
pl = pd.read_csv(os.path.join(home_dir, 'Height_0_2025251216.txt'), sep='\t')

# %%
std_list.head(20)
# Out:
#     mix Number                                         Name Note   MIX  \
# 0     1   _001                              2,3-Butanedione  NaN   NaN
# 1    13   _245                          Methyl cyanoacetate  NaN  **AK
# 2    13   _246                             Methyl glycolate  NaN  **AK
# 3     1   _004                                      Acetoin  NaN   NaN
# 4     1   _005                         Allyl isothiocyanate  NaN   NaN
# 5     1   _006                        Cyclohexyl isocyanide  NaN   NaN
# 6    13   _247             Methyl N-methylanthranilate, 98%  NaN  **AK
# 7    13   _248                S-Methyl methanethiosulfonate  NaN  **AK
# 8    13   _253                                   Nonylamine  NaN  **AK
# 9     1   _010  3-[1-(Dimethylamino)ethyl]phenol AldrichCPR  NaN   NaN
# 10   13   _256                                    3-Octanol  NaN  **AK
# 11   13   _258                                Dioctyl ether  NaN  **AK
# ...

# %%
pl.sort_values(by = 'Average Mz', ascending=True, inplace=True)

# %%
pmz = 144.175
tolerance = 0.01
quick_search_sorted(pl, 'Average Mz', pmz-tolerance, pmz+tolerance)
# Out:
#      Alignment ID  Average Rt(min)  Average Mz Metabolite name Adduct type  \
# 476           476            0.441   144.17343         Unknown      [M+H]+
#
#                Post curation result  Fill %  MS/MS assigned  Reference RT  \
# 476  found in higher mz's MsMs_2234   0.021            True           NaN
#
#      Reference m/z  ...  S pos  T pos  U pos  V pos  W pos  X pos  Y pos  \
# 476            NaN  ...      9     28      8      0      6      6      6
#
#      Z pos            1         1.1
# 476      8  15296.06782  104327.163
#
# [1 rows x 81 columns]
