# %%
# %load_ext autoreload
# %autoreload 2
import sys
import os
sys.path.insert(0, '..')
import pandas as pd
import numpy as np
from libgen.file_io import read_df
from libgen.std_utils import *
from libgen.identifier_utils import *
from libgen.chem_utils import *
from tqdm import tqdm
from libgen.std_utils import *
from libgen.constant import *
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# import chardet
#  if encoding is not sure, use this
# with open(os.path.join(master_base, conc, polarity, f'std_{tail}.csv'), 'rb') as f:
#     result = chardet.detect(f.read())
# print(result['encoding'])

# %%
master_base = '/Users/fanzhoukong/Documents/GitHub/Libgen_data/DrugLib/'
for conc in ['10x', '100x']:
    for polarity in ['pos','neg']:
        for tail in ['01', '02']:
            std_list_raw = pd.read_csv(os.path.join(master_base, conc, polarity, f'std_{tail}.csv'), encoding='Windows-1252')
            if polarity == 'pos':
                adduct = adduct_pos
            else:
                adduct = adduct_neg
            std_list_cleaned = clean_std_list(std_list_raw, adduct)
            std_list_cleaned.to_csv(os.path.join(master_base, conc, polarity, f'std_{tail}_cleaned.csv'), index=False)

# %%
std_list_cleaned[std_list_cleaned['[M]-']>0]
# Out:
#                                                   name  \
# 38   1,3,5(10)-ESTRATRIEN-3-OL-17-ONE SULPHATE, SOD...
# 51                                  LOSARTAN POTASSIUM
# 72                                     NAPROXEN SODIUM
# 75                                   LOXOPROFEN SODIUM
# 119                                    CERIVASTATIN NA
# 183  DELTA1-HYDROCORTISONE 21-HEMISUCCINATE SODIUM ...
# 231                                      CILASTATIN NA
# 361                                       PARECOXIB NA
# 363                           PANTOPRAZOLE SODIUM SALT
# 371                                 PRAVASTATIN SODIUM
# 379                                     MONTELUKAST NA
#
#                                                 smiles  \
# 38   C[C@]12CC[C@@H]3c4ccc(OS(=O)(=O)[O-])cc4CC[C@H...
# 51   CCCCc1nc(Cl)c(CO)n1Cc1ccc(-c2ccccc2-c2nnn[n-]2...
# 72                 COc1ccc2cc([C@H](C)C(=O)[O-])ccc2c1
# 75                   CC(C(=O)[O-])c1ccc(CC2CCCC2=O)cc1
# ...
